# %% [markdown]
# # Pfand Classifier bottle image preprocessor

# %% [markdown]
# A tool used to preprocess pictures for pfand project

# %%
from utils import *

# %% [markdown]
# - new size - a dimension of teh final square picture with a bottle in the center (200 x 200)
# - resize_factor - a picture quality reduction factor (1/10 for MArcin's phone photos)
# - load_dir - source directory with raw pictures of the bottle
# - save_dir - a directory for ready preprocessed pictures
# - ready_dir - a backup dir for raw pictures that have been already preprocessed

# %%
final_size = 200
resize_factor = 1/10
default_raw_size=[6000,8000]

# assign directory
load_dir = './data_raw'
save_dir = './data_cropped/'
ready_dir = './data_raw_ready/'

# test dirs
# load_dir = './test_data_raw'
# save_dir = './test_data_cropped/'
# ready_dir = './test_data_raw_ready/'

# %%
preprocess_images(load_dir, 
                  save_dir, 
                  ready_dir, 
                  resize_factor, 
                  final_size, 
                  default_raw_size, 
                  grayscale=False)
